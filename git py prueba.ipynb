# %%
print("hola fucking mundo")
# Out:
# hola fucking mundo

# %% [markdown]
# #Esto es un parrafo de Ejemplo#

# %%
class HolaMundo:
    def __init__(self):
        self.mensaje = "Hola Mundo desde la clase!"

    def mostrar_mensaje(self):
        print(self.mensaje)

# %%
input("Presiona Enter para salir...")
# Out:
# ''
